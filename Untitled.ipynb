# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris, load_wine, load_breast_cancer, load_digits, fetch_california_housing
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import entropy, variation
from DynamicHybridSampler import DynamicHybridSampler  # Make sure your class is in this file or properly imported
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_openml

# List of dataset names to load from OpenML (UCI datasets are mirrored here)
dataset_names = [
    'iris',
    'wine',
    'breast-cancer',
    'heart-disease',
    'adult',
    'bank-marketing',
    'mushroom',
    'yeast',
    'ecoli',
    'abalone'
]

def load_datasets(names):
    datasets = {}
    for name in names:
        try:
            data = fetch_openml(name, version=1, as_frame=True)
            df = data.frame
            datasets[name] = df
        except Exception as e:
            print(f"Failed to load {name}: {e}")
    return datasets

datasets = load_datasets(dataset_names)

# %%
from scipy.stats import entropy

def compute_kl_divergence(original, sample, bins=10):
    scores = {}
    numeric_cols = original.select_dtypes(include=np.number).columns
    for col in numeric_cols:
        orig_hist, _ = np.histogram(original[col].dropna(), bins=bins, density=True)
        sample_hist, _ = np.histogram(sample[col].dropna(), bins=bins, density=True)
        orig_hist += 1e-6  # Avoid zero division
        sample_hist += 1e-6
        scores[col] = entropy(orig_hist, sample_hist)
    return scores

def category_coverage(original, sample):
    coverage = {}
    cat_cols = original.select_dtypes(include='object').columns
    for col in cat_cols:
        orig_vals = set(original[col].dropna().unique())
        sample_vals = set(sample[col].dropna().unique())
        coverage[col] = len(sample_vals & orig_vals) / max(len(orig_vals), 1)
    return coverage

results_summary = {}

for name, df in datasets.items():
    print(f"Processing dataset: {name}")
    try:
        sampler = DynamicHybridSampler()
        sampler.fit(df)
        sampled = sampler.get_sample()
        explanation = sampler.get_explanation()

        kl_scores = compute_kl_divergence(df, sampled)
        coverage_scores = category_coverage(df, sampled)

        results_summary[name] = {
            "original_size": len(df),
            "sample_size": len(sampled),
            "kl_divergence": kl_scores,
            "category_coverage": coverage_scores,
            "explanation_steps": explanation[:5]  # Preview first few steps
        }
    except Exception as e:
        print(f"Failed to process {name}: {e}")
# Out:
# Profiling data...
# Sampling rare categories from categorical columns...
# Applying stratified sampling on 'class'...
# Stratified sampling on 'class' completed
# No temporal data found, applying systematic sampling...
# Systematic sampling applied with interval 1
# Checking for multi-stage sampling opportunities...
# Multistage sampling skipped due to missing hierarchical fields
# Encoding categorical columns for clustering...
# Running DBSCAN clustering...
# Silhouette Score for DBSCAN: 0.21
# Processing dataset: iris
# Included 3 samples from noise (outlier)
# Included 3 samples from cluster 0
# Included 3 samples from cluster 1
# Included 3 samples from cluster 2
# Included 3 samples from cluster 3
# Sampling from skewed numerical features using refined PPS...
# Final sample size: 100
# Sample size achieved: 100
# Profiling data...
# Sampling rare categories from categorical columns...
# Applying stratified sampling on 'class'...
# Stratified sampling on 'class' completed
# No temporal data found, applying systematic sampling...
# Systematic sampling applied with interval 1
# Checking for multi-stage sampling opportunities...
# Multistage sampling skipped due to missing hierarchical fields
# Encoding categorical columns for clustering...
# Running DBSCAN clustering...
# DBSCAN clustering did not produce multiple clusters
# Included 3 samples from noise (outlier)
# Sampling from skewed numerical features using refined PPS...
# RPPS sampling on skewed column 'Malic_acid'
# RPPS sampling on skewed column 'Magnesium'
# Final sample size: 100
# Sample size achieved: 100
# Profiling data...
# Sampling rare categories from categorical columns...
# Included 1 rare samples from column 'age'
# Included 1 rare samples from column 'inv-nodes'
# Applying stratified sampling on 'tumor-size'...
# Stratified sampling on 'tumor-size' completed
# No temporal data found, applying systematic sampling...
# Systematic sampling applied with interval 2
# Checking for multi-stage sampling opportunities...
# Multistage sampling skipped due to missing hierarchical fields
# Encoding categorical columns for clustering...
# Sampling from skewed numerical features using refined PPS...
# Processing dataset: wine
# Processing dataset: breast-cancer
# Final sample size: 100
# Sample size achieved: 100
# Profiling data...
# Sampling rare categories from categorical columns...
# No temporal data found, applying systematic sampling...
# Systematic sampling applied with interval 3
# Checking for multi-stage sampling opportunities...
# Multistage sampling skipped due to missing hierarchical fields
# Encoding categorical columns for clustering...
# Running DBSCAN clustering...
# DBSCAN clustering did not produce multiple clusters
# Included 3 samples from noise (outlier)
# Sampling from skewed numerical features using refined PPS...
# RPPS sampling on skewed column 'chol'
# RPPS sampling on skewed column 'fbs'
# RPPS sampling on skewed column 'oldpeak'
# RPPS sampling on skewed column 'ca'
# Final sample size: 100
# Sample size achieved: 100
# Profiling data...
# Sampling rare categories from categorical columns...
# Included 1 rare samples from column 'native-country'
# Applying stratified sampling on 'occupation'...
# Processing dataset: heart-disease
# Processing dataset: adult
# Stratified sampling on 'occupation' completed
# No temporal data found, applying systematic sampling...
# Systematic sampling applied with interval 488
# Checking for multi-stage sampling opportunities...
# Multistage sampling skipped due to missing hierarchical fields
# Encoding categorical columns for clustering...
# Running DBSCAN clustering...
# Silhouette Score for DBSCAN: -0.43
# Included 3 samples from noise (outlier)
# Included 3 samples from cluster 0
# Included 3 samples from cluster 1
# Included 3 samples from cluster 2
# Included 3 samples from cluster 3
# Included 3 samples from cluster 4
# Included 3 samples from cluster 5
# Included 3 samples from cluster 6
# Included 3 samples from cluster 7
# Included 3 samples from cluster 8
# Included 3 samples from cluster 9
# Included 3 samples from cluster 10
# Included 3 samples from cluster 11
# Included 3 samples from cluster 12
# Included 3 samples from cluster 13
# Included 3 samples from cluster 14
# Included 3 samples from cluster 15
# Included 3 samples from cluster 16
# Included 3 samples from cluster 17
# Included 3 samples from cluster 18
# Included 3 samples from cluster 19
# Included 3 samples from cluster 20
# Included 3 samples from cluster 21
# Included 3 samples from cluster 22
# Included 3 samples from cluster 23
# Included 3 samples from cluster 24
# Included 3 samples from cluster 25
# Included 3 samples from cluster 26
# Included 3 samples from cluster 27
# Included 3 samples from cluster 28
# Included 3 samples from cluster 29
# Included 3 samples from cluster 30
# Included 3 samples from cluster 31
# Included 3 samples from cluster 32
# Included 3 samples from cluster 33
# Included 3 samples from cluster 34
# Included 3 samples from cluster 35
# Included 3 samples from cluster 36
# Included 3 samples from cluster 37
# Included 3 samples from cluster 38
# Included 3 samples from cluster 39
# Included 3 samples from cluster 40
# Included 3 samples from cluster 41
# Included 3 samples from cluster 42
# Included 3 samples from cluster 43
# Included 3 samples from cluster 44
# Included 3 samples from cluster 45
# Included 3 samples from cluster 46
# Included 3 samples from cluster 47
# Included 3 samples from cluster 48
# Included 3 samples from cluster 49
# Included 3 samples from cluster 50
# Included 3 samples from cluster 51
# Included 3 samples from cluster 52
# Included 3 samples from cluster 53
# Included 3 samples from cluster 54
# Included 3 samples from cluster 55
# Included 3 samples from cluster 56
# Included 3 samples from cluster 57
# Included 3 samples from cluster 58
# Included 3 samples from cluster 59
# Included 3 samples from cluster 60
# Included 3 samples from cluster 61
# Included 3 samples from cluster 62
# Included 3 samples from cluster 63
# Included 3 samples from cluster 64
# Included 3 samples from cluster 65
# Included 3 samples from cluster 66
# Included 3 samples from cluster 67
# Included 3 samples from cluster 68
# Included 3 samples from cluster 69
# Included 3 samples from cluster 70
# Included 3 samples from cluster 71
# Included 3 samples from cluster 72
# Included 3 samples from cluster 73
# Included 3 samples from cluster 74
# Included 3 samples from cluster 75
# Included 3 samples from cluster 76
# Included 3 samples from cluster 77
# Included 3 samples from cluster 78
# Included 3 samples from cluster 79
# Included 3 samples from cluster 80
# Included 3 samples from cluster 81
# Included 3 samples from cluster 82
# Included 3 samples from cluster 83
# Included 3 samples from cluster 84
# Included 3 samples from cluster 85
# Included 3 samples from cluster 86
# Included 3 samples from cluster 87
# Included 3 samples from cluster 88
# Included 3 samples from cluster 89
# Included 3 samples from cluster 90
# Included 3 samples from cluster 91
# Included 3 samples from cluster 92
# Included 3 samples from cluster 93
# Included 3 samples from cluster 94
# Included 3 samples from cluster 95
# Included 3 samples from cluster 96
# Included 3 samples from cluster 97
# Included 3 samples from cluster 98
# Included 3 samples from cluster 99
# Included 3 samples from cluster 100
# Included 3 samples from cluster 101
# Included 3 samples from cluster 102
# Included 3 samples from cluster 103
# Included 3 samples from cluster 104
# Included 3 samples from cluster 105
# Included 3 samples from cluster 106
# Included 3 samples from cluster 107
# Included 3 samples from cluster 108
# Included 3 samples from cluster 109
# Included 3 samples from cluster 110
# Included 3 samples from cluster 111
# Included 3 samples from cluster 112
# Included 3 samples from cluster 113
# Included 3 samples from cluster 114
# Included 3 samples from cluster 115
# Included 3 samples from cluster 116
# Included 3 samples from cluster 117
# Included 3 samples from cluster 118
# Included 3 samples from cluster 119
# Included 3 samples from cluster 120
# Included 3 samples from cluster 121
# Included 3 samples from cluster 122
# Included 3 samples from cluster 123
# Included 3 samples from cluster 124
# Included 3 samples from cluster 125
# Included 3 samples from cluster 126
# Included 3 samples from cluster 127
# Included 3 samples from cluster 128
# Included 3 samples from cluster 129
# Included 3 samples from cluster 130
# Included 3 samples from cluster 131
# Included 3 samples from cluster 132
# Included 3 samples from cluster 133
# Included 3 samples from cluster 134
# Included 3 samples from cluster 135
# Included 3 samples from cluster 136
# Included 3 samples from cluster 137
# Included 3 samples from cluster 138
# Included 3 samples from cluster 139
# Included 3 samples from cluster 140
# Sampling from skewed numerical features using refined PPS...
# RPPS sampling on skewed column 'fnlwgt'
# Final sample size: 100
# Sample size achieved: 100
# Profiling data...
# Sampling rare categories from categorical columns...
# Applying stratified sampling on 'V2'...
# Stratified sampling on 'V2' completed
# No temporal data found, applying systematic sampling...
# Systematic sampling applied with interval 452
# Checking for multi-stage sampling opportunities...
# Multistage sampling skipped due to missing hierarchical fields
# Encoding categorical columns for clustering...
# Running DBSCAN clustering...
# Processing dataset: bank-marketing
# Silhouette Score for DBSCAN: -0.34
# Included 3 samples from noise (outlier)
# Included 3 samples from cluster 0
# Included 3 samples from cluster 1
# Included 3 samples from cluster 2
# Included 3 samples from cluster 3
# Included 3 samples from cluster 4
# Included 3 samples from cluster 5
# Included 3 samples from cluster 6
# Included 3 samples from cluster 7
# Included 3 samples from cluster 8
# Included 3 samples from cluster 9
# Included 3 samples from cluster 10
# Included 3 samples from cluster 11
# Included 3 samples from cluster 12
# Included 3 samples from cluster 13
# Included 3 samples from cluster 14
# Included 3 samples from cluster 15
# Included 3 samples from cluster 16
# Included 3 samples from cluster 17
# Included 3 samples from cluster 18
# Included 3 samples from cluster 19
# Included 3 samples from cluster 20
# Included 3 samples from cluster 21
# Included 3 samples from cluster 22
# Included 3 samples from cluster 23
# Included 3 samples from cluster 24
# Included 3 samples from cluster 25
# Included 3 samples from cluster 26
# Included 3 samples from cluster 27
# Included 3 samples from cluster 28
# Included 3 samples from cluster 29
# Included 3 samples from cluster 30
# Included 3 samples from cluster 31
# Included 3 samples from cluster 32
# Included 3 samples from cluster 33
# Included 3 samples from cluster 34
# Included 3 samples from cluster 35
# Included 3 samples from cluster 36
# Included 3 samples from cluster 37
# Included 3 samples from cluster 38
# Included 3 samples from cluster 39
# Included 3 samples from cluster 40
# Included 3 samples from cluster 41
# Included 3 samples from cluster 42
# Included 3 samples from cluster 43
# Included 3 samples from cluster 44
# Included 3 samples from cluster 45
# Included 3 samples from cluster 46
# Included 3 samples from cluster 47
# Included 3 samples from cluster 48
# Included 3 samples from cluster 49
# Included 3 samples from cluster 50
# Included 3 samples from cluster 51
# Included 3 samples from cluster 52
# Included 3 samples from cluster 53
# Included 3 samples from cluster 54
# Included 3 samples from cluster 55
# Included 3 samples from cluster 56
# Included 3 samples from cluster 57
# Included 3 samples from cluster 58
# Included 3 samples from cluster 59
# Included 3 samples from cluster 60
# Included 3 samples from cluster 61
# Included 3 samples from cluster 62
# Included 3 samples from cluster 63
# Included 3 samples from cluster 64
# Included 3 samples from cluster 65
# Included 3 samples from cluster 66
# Included 3 samples from cluster 67
# Included 3 samples from cluster 68
# Included 3 samples from cluster 69
# Included 3 samples from cluster 70
# Included 3 samples from cluster 71
# Included 3 samples from cluster 72
# Included 3 samples from cluster 73
# Included 3 samples from cluster 74
# Included 3 samples from cluster 75
# Included 3 samples from cluster 76
# Included 3 samples from cluster 77
# Included 3 samples from cluster 78
# Included 3 samples from cluster 79
# Included 3 samples from cluster 80
# Included 3 samples from cluster 81
# Included 3 samples from cluster 82
# Included 3 samples from cluster 83
# Included 3 samples from cluster 84
# Included 3 samples from cluster 85
# Included 3 samples from cluster 86
# Included 3 samples from cluster 87
# Included 3 samples from cluster 88
# Included 3 samples from cluster 89
# Included 3 samples from cluster 90
# Included 3 samples from cluster 91
# Included 3 samples from cluster 92
# Included 3 samples from cluster 93
# Included 3 samples from cluster 94
# Included 3 samples from cluster 95
# Included 3 samples from cluster 96
# Included 3 samples from cluster 97
# Included 3 samples from cluster 98
# Included 3 samples from cluster 99
# Included 3 samples from cluster 100
# Included 3 samples from cluster 101
# Included 3 samples from cluster 102
# Included 3 samples from cluster 103
# Included 3 samples from cluster 104
# Included 3 samples from cluster 105
# Included 3 samples from cluster 106
# Sampling from skewed numerical features using refined PPS...
# RPPS sampling on skewed column 'V6'
# RPPS sampling on skewed column 'V12'
# RPPS sampling on skewed column 'V13'
# RPPS sampling on skewed column 'V14'
# RPPS sampling on skewed column 'V15'
# Final sample size: 100
# Sample size achieved: 100
# Profiling data...
# Sampling rare categories from categorical columns...
# Applying stratified sampling on 'gill-color'...
# Stratified sampling on 'gill-color' completed
# No temporal data found, applying systematic sampling...
# Systematic sampling applied with interval 81
# Checking for multi-stage sampling opportunities...
# Multistage sampling skipped due to missing hierarchical fields
# Encoding categorical columns for clustering...
# Sampling from skewed numerical features using refined PPS...
# Final sample size: 100
# Sample size achieved: 100
# Profiling data...
# Sampling rare categories from categorical columns...
# Applying stratified sampling on 'class_protein_localization'...
# Stratified sampling on 'class_protein_localization' completed
# Processing dataset: mushroom
# Processing dataset: yeast
# No temporal data found, applying systematic sampling...
# Systematic sampling applied with interval 14
# Checking for multi-stage sampling opportunities...
# Multistage sampling skipped due to missing hierarchical fields
# Encoding categorical columns for clustering...
# Running DBSCAN clustering...
# Silhouette Score for DBSCAN: -0.09
# Included 3 samples from noise (outlier)
# Included 3 samples from cluster 0
# Included 3 samples from cluster 1
# Included 3 samples from cluster 2
# Included 3 samples from cluster 3
# Included 3 samples from cluster 4
# Included 3 samples from cluster 5
# Included 3 samples from cluster 6
# Sampling from skewed numerical features using refined PPS...
# RPPS sampling on skewed column 'mit'
# RPPS sampling on skewed column 'erl'
# RPPS sampling on skewed column 'pox'
# RPPS sampling on skewed column 'vac'
# RPPS sampling on skewed column 'nuc'
# Final sample size: 100
# Sample size achieved: 100
# Profiling data...
# Sampling rare categories from categorical columns...
# Applying stratified sampling on 'class'...
# Stratified sampling on 'class' completed
# No temporal data found, applying systematic sampling...
# Systematic sampling applied with interval 3
# Checking for multi-stage sampling opportunities...
# Multistage sampling skipped due to missing hierarchical fields
# Encoding categorical columns for clustering...
# Running DBSCAN clustering...
# Silhouette Score for DBSCAN: 0.25
# Included 3 samples from noise (outlier)
# Included 3 samples from cluster 0
# Included 3 samples from cluster 1
# Included 3 samples from cluster 2
# Sampling from skewed numerical features using refined PPS...
# RPPS sampling on skewed column 'lip'
# RPPS sampling on skewed column 'chg'
# Final sample size: 100
# Sample size achieved: 100
# Profiling data...
# Sampling rare categories from categorical columns...
# Included 9 rare samples from column 'Class_number_of_rings'
# Applying stratified sampling on 'Class_number_of_rings'...
# Stratified sampling on 'Class_number_of_rings' completed
# No temporal data found, applying systematic sampling...
# Systematic sampling applied with interval 41
# Checking for multi-stage sampling opportunities...
# Multistage sampling skipped due to missing hierarchical fields
# Encoding categorical columns for clustering...
# Running DBSCAN clustering...
# Processing dataset: ecoli
# Processing dataset: abalone
# Silhouette Score for DBSCAN: 0.13
# Included 3 samples from noise (outlier)
# Included 3 samples from cluster 0
# Included 3 samples from cluster 1
# Included 3 samples from cluster 2
# Included 3 samples from cluster 3
# Included 3 samples from cluster 4
# Included 3 samples from cluster 5
# Included 3 samples from cluster 6
# Sampling from skewed numerical features using refined PPS...
# RPPS sampling on skewed column 'Height'
# Final sample size: 100
# Sample size achieved: 100

# %%
for dataset, metrics in results_summary.items():
    print(f"\nDataset: {dataset}")
    print(f"Original Size: {metrics['original_size']}, Sample Size: {metrics['sample_size']}")
    print("KL Divergence:")
    for col, score in metrics['kl_divergence'].items():
        print(f"  {col}: {score:.4f}")
    print("Category Coverage:")
    for col, coverage in metrics['category_coverage'].items():
        print(f"  {col}: {coverage:.2%}")
    print("Explanation Steps:")
    for step in metrics['explanation_steps']:
        print(f"  - {step}")
# Out:
# Dataset: iris
# Original Size: 150, Sample Size: 100
# KL Divergence:
#   sepallength: 0.1006
#   sepalwidth: 0.1367
#   petallength: 0.0608
#   petalwidth: 0.7295
# Category Coverage:
# Explanation Steps:
#   - Profiling data...
#   - Sampling rare categories from categorical columns...
#   - Applying stratified sampling on 'class'...
#   - Stratified sampling on 'class' completed
#   - No temporal data found, applying systematic sampling...
#
# Dataset: wine
# Original Size: 178, Sample Size: 100
# KL Divergence:
#   Alcohol: 0.3138
#   Malic_acid: 0.1046
#   Ash: 0.5451
#   Alcalinity_of_ash: 0.3135
#   Magnesium: 0.3637
#   Total_phenols: 0.2285
#   Flavanoids: 0.4095
#   Nonflavanoid_phenols: 0.0352
#   Proanthocyanins: 0.3462
#   Color_intensity: 0.0993
#   Hue: 0.3900
#   OD280%2FOD315_of_diluted_wines: 0.0676
#   Proline: 0.0677
# Category Coverage:
# Explanation Steps:
#   - Profiling data...
#   - Sampling rare categories from categorical columns...
#   - Applying stratified sampling on 'class'...
#   - Stratified sampling on 'class' completed
#   - No temporal data found, applying systematic sampling...
#
# Dataset: breast-cancer
# Original Size: 286, Sample Size: 100
# KL Divergence:
# Category Coverage:
# Explanation Steps:
#   - Profiling data...
#   - Sampling rare categories from categorical columns...
#   - Included 1 rare samples from column 'age'
#   - Included 1 rare samples from column 'inv-nodes'
#   - Applying stratified sampling on 'tumor-size'...
#
# Dataset: heart-disease
# Original Size: 303, Sample Size: 100
# KL Divergence:
#   age: 0.1720
#   sex: 0.0080
#   cp: 0.0339
#   trestbps: 0.6185
#   chol: 0.3979
#   fbs: 0.0035
#   restecg: 0.0016
#   thalach: 0.3179
#   exang: 0.0243
#   oldpeak: 0.2160
#   slope: 0.0183
#   ca: 0.0186
#   thal: 8.8883
#   target: 0.0004
# Category Coverage:
# Explanation Steps:
#   - Profiling data...
#   - Sampling rare categories from categorical columns...
#   - No temporal data found, applying systematic sampling...
#   - Systematic sampling applied with interval 3
#   - Checking for multi-stage sampling opportunities...
#
# Dataset: adult
# Original Size: 48842, Sample Size: 100
# KL Divergence:
#   fnlwgt: 0.1365
#   education-num: 0.1322
# Category Coverage:
# Explanation Steps:
#   - Profiling data...
#   - Sampling rare categories from categorical columns...
#   - Included 1 rare samples from column 'native-country'
#   - Applying stratified sampling on 'occupation'...
#   - Stratified sampling on 'occupation' completed
#
# Dataset: bank-marketing
# Original Size: 45211, Sample Size: 100
# KL Divergence:
#   V1: 0.1719
#   V6: 0.1708
#   V10: 0.0712
#   V12: 0.3894
#   V13: 0.1477
#   V14: 0.5145
#   V15: 0.2573
# Category Coverage:
# Explanation Steps:
#   - Profiling data...
#   - Sampling rare categories from categorical columns...
#   - Applying stratified sampling on 'V2'...
#   - Stratified sampling on 'V2' completed
#   - No temporal data found, applying systematic sampling...
#
# Dataset: mushroom
# Original Size: 8124, Sample Size: 100
# KL Divergence:
# Category Coverage:
# Explanation Steps:
#   - Profiling data...
#   - Sampling rare categories from categorical columns...
#   - Applying stratified sampling on 'gill-color'...
#   - Stratified sampling on 'gill-color' completed
#   - No temporal data found, applying systematic sampling...
#
# Dataset: yeast
# Original Size: 1484, Sample Size: 100
# KL Divergence:
#   mcg: 0.3068
#   gvh: 0.5651
#   alm: 1.0638
#   mit: 0.5436
#   erl: 0.0099
#   pox: 16.0557
#   vac: 0.3461
#   nuc: 0.1280
# Category Coverage:
# Explanation Steps:
#   - Profiling data...
#   - Sampling rare categories from categorical columns...
#   - Applying stratified sampling on 'class_protein_localization'...
#   - Stratified sampling on 'class_protein_localization' completed
#   - No temporal data found, applying systematic sampling...
#
# Dataset: ecoli
# Original Size: 336, Sample Size: 100
# KL Divergence:
#   mcg: 0.1252
#   gvh: 0.9450
#   lip: 0.0000
#   chg: 0.0034
#   aac: 0.3727
#   alm1: 0.2993
#   alm2: 0.5976
# Category Coverage:
# Explanation Steps:
#   - Profiling data...
#   - Sampling rare categories from categorical columns...
#   - Applying stratified sampling on 'class'...
#   - Stratified sampling on 'class' completed
#   - No temporal data found, applying systematic sampling...
#
# Dataset: abalone
# Original Size: 4177, Sample Size: 100
# KL Divergence:
#   Length: 0.2984
#   Diameter: 0.3346
#   Height: 3.9973
#   Whole_weight: 0.0811
#   Shucked_weight: 0.1041
#   Viscera_weight: 0.2611
#   Shell_weight: 0.0776
# Category Coverage:
# Explanation Steps:
#   - Profiling data...
#   - Sampling rare categories from categorical columns...
#   - Included 9 rare samples from column 'Class_number_of_rings'
#   - Applying stratified sampling on 'Class_number_of_rings'...
#   - Stratified sampling on 'Class_number_of_rings' completed
